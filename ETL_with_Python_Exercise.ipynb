# %% [markdown]
# <a href="https://colab.research.google.com/github/barbarazucatti/python-etl-learning/blob/main/ETL_with_Python_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
